# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
import re
import matplotlib

# %%
Jan = pd.read_csv('Sales_January_2019.csv')
Feb = pd.read_csv('Sales_February_2019.csv')
Mar = pd.read_csv('Sales_March_2019.csv')
Apr = pd.read_csv('Sales_April_2019.csv')
May = pd.read_csv('Sales_May_2019.csv')
Jun = pd.read_csv('Sales_June_2019.csv')
Jul = pd.read_csv('Sales_July_2019.csv')
Aug = pd.read_csv('Sales_August_2019.csv')
Sep = pd.read_csv('Sales_September_2019.csv')
Oct = pd.read_csv('Sales_October_2019.csv')
Nov = pd.read_csv('Sales_November_2019.csv')
Dec = pd.read_csv('Sales_December_2019.csv')

# %%
Jan_Dec = [Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec]
raw_data = pd.concat(Jan_Dec)
#raw_data.info()

# %%
null_values = raw_data[(raw_data.isnull()).any(axis = 1)]
#null_values.info()

# %%
raw_data.dropna(subset = ["Order ID"], inplace=True)
#raw_data.info()
raw_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address  Customer ID
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215        17382
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035        52119
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016        44364
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001        49587
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301        85699

# %%
col_rep = raw_data[raw_data.loc[:, 'Order ID'].str.contains('Order ID')]
raw_data.head(1073)
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1         700
# 1       141235  Lightning Charging Cable                 1       14.95
# 2       141236          Wired Headphones                 2       11.99
# 3       141237          27in FHD Monitor                 1      149.99
# 4       141238          Wired Headphones                 1       11.99
# ...        ...                       ...               ...         ...
# 1072    142259                  LG Dryer                 1       600.0
# 1073  Order ID                   Product  Quantity Ordered  Price Each
# 1074    142260    AAA Batteries (4-pack)                 2        2.99
# 1075    142261                    iPhone                 1         700
# 1076    142261          Wired Headphones                 1       11.99
#
#           Order Date                        Purchase Address  Customer ID
# ...

# %%
raw_data = raw_data.loc[raw_data['Product'] != 'Product']
raw_data.head(1072)

#raw_data.drop(raw_data.index[raw_data['myvar'] == 'specific_name'], inplace = True)

#condition = raw_data[ (raw_data['Order ID'] == 'Order ID') & (raw_data['Product'] == 'Product') &
 #                    (raw_data['Quantity Ordered'] == 'Quantity Ordered') & (raw_data['Price Each'] == 'Price Each')
  #                   & (raw_data['Order Date'] == 'Order Date') & (raw_data['Purchase Address'] == 'Purchase Address')
   #                  & (raw_data['Customer ID'] == 'Customer ID')].index
#raw_data.drop(condition, inplace = True)
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 1071   142258  Lightning Charging Cable                1      14.95
# 1072   142259                  LG Dryer                1      600.0
# 1074   142260    AAA Batteries (4-pack)                2       2.99
# 1075   142261                    iPhone                1        700
# 1076   142261          Wired Headphones                1      11.99
#
#           Order Date                        Purchase Address  Customer ID
# 0     01/22/19 21:25         944 Walnut St, Boston, MA 02215        17382
# ...

# %%
raw_data[['Date', 'Time']] = raw_data['Order Date'].str.split(' ', expand = True)
raw_data.head(2)
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
#
#        Order Date                  Purchase Address  Customer ID      Date  \
# 0  01/22/19 21:25   944 Walnut St, Boston, MA 02215        17382  01/22/19
# 1  01/28/19 14:15  185 Maple St, Portland, OR 97035        52119  01/28/19
#
#     Time
# 0  21:25
# 1  14:15

# %%
raw_data = raw_data.drop(columns ='Order Date')
raw_data.head(2)
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
#
#                    Purchase Address  Customer ID      Date   Time
# 0   944 Walnut St, Boston, MA 02215        17382  01/22/19  21:25
# 1  185 Maple St, Portland, OR 97035        52119  01/28/19  14:15

# %%
raw_data['Date'] = raw_data['Date'].str.replace('/2019', '/19')
raw_data.head(2)
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
#
#                    Purchase Address  Customer ID      Date   Time
# 0   944 Walnut St, Boston, MA 02215        17382  01/22/19  21:25
# 1  185 Maple St, Portland, OR 97035        52119  01/28/19  14:15

# %%
raw_data["Date"] = raw_data["Date"].apply(lambda a : dt.strptime(a, "%m/%d/%y"))
#col_rep = raw_data[raw_data.loc[:, 'Date'].str.contains('Order')]
#col_rep

# %%
raw_data[['House No','City', 'State']] = raw_data['Purchase Address'].str.split(',', expand = True)

# %%
raw_data['State']  = raw_data['State'].str.lstrip()
raw_data[['States', 'Zip Code']] = raw_data['State'].str.split(' ', expand = True)

# %%
raw_data = raw_data.drop(columns = ['State'])
raw_data = raw_data.drop(columns = ['Purchase Address'])
raw_data.head(2)
# Out:
#   Order ID                   Product Quantity Ordered Price Each  Customer ID  \
# 0   141234                    iPhone                1        700        17382
# 1   141235  Lightning Charging Cable                1      14.95        52119
#
#         Date   Time       House No       City States Zip Code
# 0 2019-01-22  21:25  944 Walnut St     Boston     MA    02215
# 1 2019-01-28  14:15   185 Maple St   Portland     OR    97035

# %%
raw_data['Amount Paid'] = raw_data['Quantity Ordered'] * [ 'Price Each']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
monthly_revenue = pd.DataFrame(updated_data.groupby('Month')['Amount'].sum()).reset_index(drop = False)
monthly_revenue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-6f3498de7d3d> in <module>
# ----> 1 monthly_revenue = pd.DataFrame(updated_data.groupby('Month')['Amount'].sum()).reset_index(drop = False)
#       2 monthly_revenue
#
# NameError: name 'updated_data' is not defined

# %%
revenue_by_products = pd.DataFrame(updated_data.groupby('Product')['Amount'].sum()).reset_index(drop = False)
revenue_by_products

# %%
look_up = {'01': 'Jan', '02': 'Feb', '03': 'Mar', '04': 'Apr', '05': 'May',
            '06': 'Jun', '07': 'Jul', '08': 'Aug', '09': 'Sep', '10': 'Oct', '11': 'Nov', '12': 'Dec'}
